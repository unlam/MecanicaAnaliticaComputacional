# %% [markdown]
# # Coordenadas generalizadas | Ligaduras | Energías cinética y potencial
#
# ## Pesas acopladas rotando en torno a eje
# Landau $\S$ 5 ej. 4

# %% [markdown]
# [![ingenieria_logo_schwarz.png](data:image/png;base64,...)](https://ingenieria.unlam.edu.ar/)
# [![by-nc-sa_80x15.png](data:image/png;base64,...)](https://creativecommons.org/licenses/by-sa/4.0/deed.es_ES)
# 2026 [Víctor A. Bettachini](mailto:vbettachini@unlam.edu.ar)
#
# ---

# %% [markdown]
# La pieza con $m_2$ se desplaza sobre un eje vertical, y todo el sistema gira con una velocidad angular $\Omega$ _constante_ en torno a ese eje.
# Está unida por barras de longitud $a$ y masa despreciable a otras pesas de masa $m_1$.
# A su vez estas penden de sendas barras idénticas del punto fijo, $A$, que describen un ángulo variable de apertura respecto al eje $\theta$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Tareas

# %% [markdown]
# 1. Calcule la energía cinética para cada una de las tres masas y exprese en la forma más compacta posible la del sistema en su conjunto.
#
# Resultado:
# $$
# T_{traslaci\acute{o}n} = a^{2} \left( m_{1} \left( \Omega^{2} \sin^{2}{\left(\theta \right)} + \dot{\theta}^{2}\right) + 2 m_{2} \sin^{2}{\left(\theta \right)} \dot{\theta}^{2} \right) \\
# $$

# %%
# aquí va el código.

# %% [markdown]
# 2. Haga lo propio con la energía potencial.
#
# Resultado:
# $$
# V_{gravitatoria} = - 2 a g \left(m_{1} + m_{2}\right) \cos{\left(\theta \right)}
# $$

# %%
# aquí va el código.

# %% [markdown]
# ### Ilustraciones adicionales

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En estas ilustraciones indicamos el punto $A$, de donde tenemos _agarrado_ al sistema, con la _pelota de arriba_.
#
# Todo gira en torno al eje rosa con velocidad angular $\Omega$ _constante_.
# Por lo tanto, las dos partículas de los laterales, las de masa $m_1$, rotan entrando y saliendo del plano de la pantalla (imagen de abajo).
# Esto es equivalente a pensar que el plano celeste de la imagen rota completo sobre el eje rosa.
#
# La pieza de masa $m_2$ es un dispositivo pasante (un buje) que puede ir para arriba y abajo sin rozamiento sobre el eje vertical (rosa).
# Si la pieza de abajo sube, todos los ángulos cambian lo mismo, porque las longitudes de las barras naranjas son todas iguales.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
