# %% [markdown]
# # Coordenadas generalizadas | Ligaduras | Energías cinética y potencial
#
# ## Péndulo con punto de suspensión en rotación
# Marion (e) ex. 7.5
# Landau $\S$ 5 ej. 3

# %% [markdown]
# [![ingenieria_logo_schwarz.png](data:image/png;base64,...)](https://ingenieria.unlam.edu.ar/)
# [![by-nc-sa_80x15.png](data:image/png;base64,...)](https://creativecommons.org/licenses/by-sa/4.0/deed.es_ES)
# 2026 [Víctor A. Bettachini](mailto:vbettachini@unlam.edu.ar)
#
# ---

# %% [markdown]
# Una partícula de masa $m$ pende de una barra rígida de longitud $b$.
# El punto de suspensión engarzado en un aro de radio $a$ dispuesto verticalmente rota respecta a su centro con una frecuencia $\omega$ _constante_.
# Se asume que todas las posiciones se encuentran en un único plano bidimensional y que la masa de la barra rígida tiene masa despreciable frente a $m$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Tareas

# %% [markdown]
# 1. Calcule la energía cinética, $T$ y potencial, $V$ de la partícula con masa $m$.
#
# Resultado:
# $$
# T_{traslaci\acute{o}n} = \dfrac{m \left(a^{2} \omega^{2} - 2 a b \omega \sin{\left(\omega t - \theta \right)} \dot{\theta} + b^{2} \dot{\theta}^{2}\right)}{2}\\
# V_{gravitatoria} = g m \left(a \sin{\left(\omega t \right)} - b \cos{\left(\theta \right)}\right)
# $$

# %%
# aquí va el código.
