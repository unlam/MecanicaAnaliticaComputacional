# %% [markdown]
# # Coordenadas generalizadas | Ligaduras | Energías cinética y potencial
#
# ## Péndulo doble
# Landau $\S$ 5 ej. 1

# %% [markdown]
# [![ingenieria_logo_schwarz.png](data:image/png;base64,...)](https://ingenieria.unlam.edu.ar/)
# [![by-nc-sa_80x15.png](data:image/png;base64,...)](https://creativecommons.org/licenses/by-sa/4.0/deed.es_ES)
# 2026 [Víctor A. Bettachini](mailto:vbettachini@unlam.edu.ar)
#
# ---

# %% [markdown]
# Una barra rígida de longitud $\ell_1$ tiene una masa despreciable respecto a la de la partícula de masa $m_1$ fija a su extremo.
# A su vez de esta última pende otra barra rígida, de longitud $\ell_2$ que en su extremo tiene otra partícula de masa $m_2$, también mucho mayor que aquella de la barra.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### a) Obtener la energía cinética, $T$, y potencial, $V$, en función de las coordenadas de la figura
# Resultado:
# $$
# \begin{align}
# T_{traslaci\acute{o}n} = \dfrac{\ell_{1}^{2} m_{1} \dot{\varphi}_{1}^{2}}{2} + \dfrac{m_{2} \left(\ell_{1}^{2} \dot{\varphi}_{1}^{2} + 2 \ell_{1} \ell_{2} \cos{\left(\varphi_{1} - \varphi_{2} \right)} \dot{\varphi}_{1} \dot{\varphi}_{2} + \ell_{2}^{2} \dot{\varphi}_{2}^{2}\right)}{2}
# \\[1 pc]
# V_{gravitatoria} = - g \left(\ell_{1} m_{1} \cos{\left(\varphi_{1} \right)} + \ell_{1} m_{2} \cos{\left(\varphi_{1} \right)} + \ell_{2} m_{2} \cos{\left(\varphi_{2} \right)}\right)
# \end{align}
# $$

# %%
# aquí va el código.

# %% [markdown]
# ### b) Recobrar solución del péndulo rígido
# Establezca $m_1 = 0$, $\varphi_1 = \varphi_2 = \varphi$ y $\ell_1 = \ell_2 = \frac{\ell}{2}$ a través de la función de substitución de `SymPy`.
# Verifique que se obtiene el $T$ y $V$ de un único péndulo rígido ideal.

# %%
# aquí va el código.
