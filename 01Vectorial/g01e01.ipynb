# %% [markdown]
# # Cinemática vectorial
#
# ## Posición suma

# %% [markdown]
# [![ingenieria_logo_schwarz.png](data:image/png;base64,...)](https://ingenieria.unlam.edu.ar/)
# [![by-nc-sa_80x15.png](data:image/png;base64,...)](https://creativecommons.org/licenses/by-sa/4.0/deed.es_ES)
# 2026 [Víctor A. Bettachini](mailto:vbettachini@unlam.edu.ar)
#
# ---

# %% [markdown]
# Para cada punto del ejercicio use al menos una celda de código.
#
# Es buena práctica interponer otras celdas, pero de texto, en las que se indique de qué punto se trata.
# En estas celdas de texto puede acotar sus aclaraciones.

# %% [markdown]
# Realice los siguientes pasos definiendo las variables necesarias en `SymPy` para que pueda verificar los resultados.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### a) Guardar en una variable llamada `a_r` un vector que indique la posición $\vec{r}_a = 3 \hat{e}_x + 0 \hat{e}_y + 5 \hat{e}_z$.
#
# Luego, en otra celda escriba `a_r`, y ejecútela para verificar que el vector fue guardado correctamente.

# %%
# aquí va el código.

# %% [markdown]
# ### b) Guardar $\vec{r}_b = -5 \hat{e}_x + (-5) \hat{e}_y + 7 \hat{e}_z$ en `b_r`.
# Como en el paso anterior, verifique que el vector fue guardado correctamente.

# %%
# aquí va el código.

# %% [markdown]
# ### c) Restar las variables correspondientes para realizar $\Delta \vec{r}_{a \to b} = \vec{r}_b - \vec{r}_a$ y guardar el resultado en `ab_deltaR`
# Verifique lo guardado.

# %%
# aquí va el código.

# %% [markdown]
# ### d) Guardar en `c_r` (vector posición del punto c) el resultado de $\vec{r}_a +\Delta \vec{r}_{a \to b}$
# Verifique.

# %%
# aquí va el código.

# %% [markdown]
# ### e) Para verificar que todo se hizo bien basta con leer `c_r` y comprobar que $\vec{r}_c = \vec{r}_b$
# Para eso verifique el contenido de `c_r`

# %%
# aquí va el código.
