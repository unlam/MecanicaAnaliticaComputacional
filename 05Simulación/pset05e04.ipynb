# %% [markdown]
# # Máquina de Atwood compuesta
# Marion (English) ex 7.8
#
# Unidad: Simulación

# %% [markdown]
# [![ingenieria_logo_schwarz.png](data:image/png;base64,...)](https://ingenieria.unlam.edu.ar/)
# [![by-nc-sa_80x15.png](data:image/png;base64,...)](https://creativecommons.org/licenses/by-sa/4.0/deed.es_ES)
# 2026 [Víctor A. Bettachini](mailto:vbettachini@unlam.edu.ar)
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Tareas

# %% [markdown]
# ### a) Resuelva numéricamente la ecuación de Euler-Lagrange que corresponda a cada coordenada generalizada.

# %% [markdown]
# Parámetros físicos:
#
# $\ell_\text{superior} = 15\,\mathrm{m}$
#
# $R_{\text{polea sup}} = 0.5\,\mathrm{m}$
#
# $\ell_\text{inferior} = 15\,\mathrm{m}$
#
# $R_{\text{polea inf}} = 0.5\,\mathrm{m}$
#
#
# $m_1 = 1\,\mathrm{kg}$
#
# $m_2 = 2\,\mathrm{kg}$
#
# $m_3 = 3,\,\mathrm{kg}$
#
# $M_{\text{polea sup}} = 4\,\mathrm{kg}$
#
# $M_{\text{polea inf}} = 4\,\mathrm{kg}$
#
# Intervalo de tiempo:
#
# $t = 0 \,\mathrm{a}\, 5\,\mathrm{s}$
#
# Condiciones iniciales:
#
# $y_1(t=0) = 1\,\mathrm{m}$
#
# $\dot{y}_1(t=0) = 0$
#
# $y_2(t=0) = 2\,\mathrm{m}$
#
# $\dot{y}_2(t=0) = 0$
#
# La aceleración gravitatoria tiene por magnitud $|\vec{g}| = 9.81\,\mathrm{\frac{m}{s^2}}$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# aquí va el código.

# %% [markdown]
# ### b) Grafique tales soluciones.

# %%
# aquí va el código.
