# %% [markdown]
# # Péndulo de pesas deslizantes y acopladas
# Ligaduras

# %% [markdown]
# [![ingenieria_logo_schwarz.png](data:image/png;base64,...)](https://ingenieria.unlam.edu.ar/)
# [![by-nc-sa_80x15.png](data:image/png;base64,...)](https://creativecommons.org/licenses/by-sa/4.0/deed.es_ES)
# 2026 [Víctor A. Bettachini](mailto:vbettachini@unlam.edu.ar)
#
# ---

# %% [markdown]
# Dos pesas de masa $m_1$ y $m_2$ están unidas por una barra rígida inextensible de longitud $\ell$ y masa despreciable frente a las anteriores.
# La de $m_1$ puede deslizar sin rozamiento sobre un eje horizontal y la de $m_2$ en uno vertical.
# La barra establece un vínculo entre las respectivas coordenadas que definen sus posiciones, $x$ e $y$, desde la unión $O$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Tareas

# %% [markdown]
# ### a) Use la función de vínculo para expresar las posiciones solo en función de $y$

# %%
# aquí va el código.

# %% [markdown]
# ### b) Calcule la aceleración de la pesa de $m_2$
# Resultado:
# $$
# \ddot{y} =
# \dfrac{- \ell^{2} m_{1} y \dot{y}^{2} + g m_{2} \left(\ell^{2} - y^{2}\right)^{2}}{\ell^{4} m_{2} + \ell^{2} m_{1} y^{2} - 2 \ell^{2} m_{2} y^{2} - m_{1} y^{4} + m_{2} y^{4}}
# $$

# %%
# aquí va el código.

# %% [markdown]
# ### c) 	Ahora realice lo mismo pero usando $\theta$ como coordenada generalizada.
#
# Resultado:
# $$
# \ddot{\theta} = \dfrac{\left(\ell m_{1} \cos{\left(\theta \right)} \dot{\theta}^{2} - \ell m_{2} \cos{\left(\theta \right)} \dot{\theta}^{2} - g m_{2}\right) \sin{\left(\theta \right)}}{\ell \left(m_{1} \cos^{2}{\left(\theta \right)} + m_{2} \sin^{2}{\left(\theta \right)}\right)}
# $$

# %%
# aquí va el código.

# %% [markdown]
# ### d) ¿Con cuál de estas coordenadas las expresiones de energía resultan más "informativas"?

# %% [markdown]
# (Escriba acá un texto)
