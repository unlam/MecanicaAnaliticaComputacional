# %% [markdown]
# # Partícula deslizando sobre una semiesfera
# Marion (e) ex. 7.10
#
# Unidad: Fuerzas de ligadura

# %% [markdown]
# [![ingenieria_logo_schwarz.png](data:image/png;base64,...)](https://ingenieria.unlam.edu.ar/)
# [![by-nc-sa_80x15.png](data:image/png;base64,...)](https://creativecommons.org/licenses/by-sa/4.0/deed.es_ES)
# 2026 [Víctor A. Bettachini](mailto:vbettachini@unlam.edu.ar)
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La partícula de masa $m$, considerada puntual, desliza sobre una semiesfera de radio $R$ sin fricción.
# Esto impone que $\rho = R$ y $\dot{\rho} \equiv 0$.
#
# Para obtener $\theta^\mathrm{despegue}$ hay que tener presente que:
# - Cuando la fuerza de ligadura para la coordenada radial, $Q_{\rho}$, sea nula es el momento en que se produce el despegue.
# - Al no haber rozamiento la energía mecánica (cinética + potencial) es constante.

# %% [markdown]
# ## Tareas

# %% [markdown]
# ### a) Encuentre la fuerza de la ligadura.
# Resultado:
# $$
# Q_{\rho} = m \left(- R \dot{\theta}^{2} + g \cos{\left(\theta \right)}\right)
# $$

# %%
# aquí va el código.

# %% [markdown]
# ### b) 	Escriba una ecuación para igualar la energía mecánica inicial con la de despegue.
# Para esto tendrá que substituir en su expresión general una vez para las condiciones iniciales (cuando estaba arriba) y otra vez para el momento del despegue.

# %%
# aquí va el código.

# %% [markdown]
# ### c) Con la ecuación que iguala las energías mecánicas y con la de $Q_{\rho}= 0$ (al momento del despegue) podrá calcular el ángulo en que la partícula se despega de la semiesfera.
# Resultado:
# $$
# \theta^\mathrm{despegue} \approx 48.19^\circ
# $$

# %%
# aquí va el código.
