# %% [markdown]
# # Ecuación de Euler-Lagrange
#
# ## Resorte enrollado en un brazo de una "T"

# %% [markdown]
# [![ingenieria_logo_schwarz.png](data:image/png;base64,...)](https://ingenieria.unlam.edu.ar/)
# [![by-nc-sa_80x15.png](data:image/png;base64,...)](https://creativecommons.org/licenses/by-sa/4.0/deed.es_ES)
# 2026 [Víctor A. Bettachini](mailto:vbettachini@unlam.edu.ar)
#
# ---

# %% [markdown]
# Una pieza rígida en forma de T consiste en una larga varilla soldada perpendicularmente a otra de longitud $\ell$ que pivotea en torno a un origen.
# La T gira sobre un plano horizontal con velocidad angular constante $\omega$.
# Una partícula de masa $m$ muy superior a la de la T, por la que esta última es despreciable, puede desplazarse libremente en la primera varilla y está conectada a la intersección de ambas por un resorte de constante elástica $k$ y longitud natural nula.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Encuentre una ecuación para la dinámica en función de $d$, la distancia de la partícula a la intersección.
# Resultado:
# $$
# - \omega^{2} m d + k d + m \ddot{d} = 0
# $$
# 2. Existe un "valor especial" para $\omega$. ¿Cuál sería y que implicaría para $d(t)$?

# %% [markdown]
# ### Resolución

# %%
# aquí va el código.
