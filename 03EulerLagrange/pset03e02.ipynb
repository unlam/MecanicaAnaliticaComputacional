# %% [markdown]
# # Ecuación de Euler-Lagrange
#
# ## Plano inclinado móvil

# %% [markdown]
# [![ingenieria_logo_schwarz.png](data:image/png;base64,...)](https://ingenieria.unlam.edu.ar/)
# [![by-nc-sa_80x15.png](data:image/png;base64,...)](https://creativecommons.org/licenses/by-sa/4.0/deed.es_ES)
# 2026 [Víctor A. Bettachini](mailto:vbettachini@unlam.edu.ar)
#
# ---

# %% [markdown]
# Un bloque de masa $m_1$ está originalmente inmóvil sobre un plano de inclinación $\theta$ que no le presenta fricción y de masa $M$.
# Este último puede deslizar sobre la superficie horizontal que tampoco le presenta fricción alguna.
# Denomine con $c$ la coordenada para la posición de este último, en la dirección y sentido indicado por la flecha; y con $d$ la del bloque superior en el sentido descendente.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Obtenga la ecuación de Euler-Lagrange para $c$ y aquella para $d$.
# Resultado:
# $$
# M \ddot{c} - m_1 \cos{\left(\theta \right)} \ddot{d} + m_1 \ddot{c} = 0
# \\[5 pt]
# m_1 \left(g \sin{\left(\theta \right)} + \cos{\left(\theta \right)} \ddot{c} - \ddot{d }\right) = 0
# $$

# %% [markdown]
# Puede notarse que como se obtuvo un sistema de dos ecuaciones diferenciales ligadas, ésto no permite responder a un interrogante como: _De soltar el bloque más pequeño, ¿qué aceleración tiene el plano?_.
#
# En la siguiente unidad se empleará `SymPy` para resolver tales sistemas.

# %% [markdown]
# ### Resolución

# %%
# aquí va el código.
