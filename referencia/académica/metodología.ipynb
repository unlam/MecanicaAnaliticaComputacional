# %% [markdown]
# # Metodología y herramientas del curso

# %% [markdown]
# [![ingenieria_logo_schwarz.png](data:image/png;base64,...)](https://ingenieria.unlam.edu.ar/)
# [![by-nc-sa_80x15.png](data:image/png;base64,...)](https://creativecommons.org/licenses/by-sa/4.0/deed.es_ES)
# 2026 [Víctor A. Bettachini](mailto:vbettachini@unlam.edu.ar)
#
# ---

# %% [markdown]
# ## Código para resolver problemas de mecánica

# %% [markdown]
# - Se escribirá código usando el lenguaje de programación general [Python](https://www.python.org/)
# - Escribir código $\neq$ programar
#     - **Programar**: Implica analizar y modelar matemáticamente un problema (lógica), idear y comparar alternativas, cuál es la mejor considerando contexto de uso, restricciones, arquitectura del equipo informático y capacidades del humano que le opere.
#         - Requiere **bastante** estudio y esfuerzo.
#         - Cualquier estudiante de ingeniería **puede** aprender a programar.
#     - **Escribir código**: Permite obtener soluciones informáticas valíendose de un lenguaje de programación.
#         - Requiere **poco** estudio y esfuerzo
#         - Todo estudiante de ingeniería **DEBE** aprender a escribir código.
#         - Grandes modelos de lenguaje (LLMs) facilitan la tarea: [ChatGPT](https://chat.openai.com/), [DeepSeek](https://chat.deepseek.com/), [Mistral](https://chat.mistral.ai/), [Qwen](https://chat.qwen.ai/), [Claude](https://claude.ai), [Copilot](https://github.com/features/copilot), etc.
# - Se emplea un mínimo de funciones de bibliotecas:
#     - [SymPy](https://www.sympy.org/es/index.html) para álgebra y análisis simbólico
#     - [NumPy](https://numpy.org/) y [SciPy](https://scipy.org/) para cálculo numérico
#     - [matplotlib](https://matplotlib.org/) para generar representaciones visuales de los resultados

# %% [markdown]
# ## Cuadernos Jupyter: el entorno de trabajo de la asignatura

# %% [markdown]
# ![/home/vbettachini/documents/universitet/unlam/MecanicaAnaliticaComputacional/88presentación/figuras/screenshot_JupyterLab.png](data:image/png;base64,...)
#
# **Figura 1**: Captura de pantalla de la resolución de un ejercicio en un cuaderno Jupyter.

# %% [markdown]
# Los **[cuadernos Jupyter](https://jupyter.org/)** se aplican en el ámbito universitario para la resolución de problemas y la investigación computacional, desde las ciencias a la ingeniería, pasando por las humanidades. Al entrelazar la computación con el contenido disciplinar, los cuadernos Jupyter ponen en práctica el pensamiento computacional, no para acotarse al mundo de las ciencias e ingenierías de la computación, sino para extender el alcance de toda actividad académica en el ámbito de la educación superior.
#
# - Los cuadernos Jupyter se despliegan en un navegador, incluso en un teléfono.
# - Están segmentados en celdas de:
#     - **anotación**: textos, figuras, multimedia y simbología en notación matemática estándar,
#     - **código**: cálculo simbólico, representación gráfica y simulación numérica.
# - Esto hace de Los cuadernos un soporte ideal para entregar a los alumnos:
#     - El material teórico.
#     - Ejercicios resueltos.
# - Son **reutilizables**, esto es, a los alumnos les basta copiarles y modificarles para:
#     - Resolver cada ejercicio de la guía de problemas.
#     - Hacer una devolución de los mismos al docente para la evalución.

# %% [markdown]
# ### Ejecución de los cuadernos Jupyter

# %% [markdown]
# ![/home/vbettachini/documents/universitet/unlam/MecanicaAnaliticaComputacional/88presentación/figuras/comentariosColab.png](data:image/png;base64,...)
#
# **Figura 2**: Captura de pantalla de la resolución de un ejercicio en Google Colaboratory con comentarios del docente.

# %% [markdown]
# - Para ejecutar cuadernos Jupyter puede utilizarse [Google Colaboratory](https://colab.research.google.com/)
#     - **Gratuito**
#     - **En línea** (web)
#         - Solo se requiere un navegador para trabajar con los cuadernos
#     - **En la nube**
#         - No hay que lidiar con archivos
#         - Nunca se pierde el trabajo
#         - Puede trabajarse desde cualquier lugar y en cualquier hora
#     - **Colaborativo**
#         - Alumno(s) y docente pueden escribir en un mismo cuaderno
#             - Comentarios y correcciones asincrónicas por parte del docente
#             - Habilita el trabajo grupal **remoto**

# %% [markdown]
# ## [Aula invertida](https://es.wikipedia.org/wiki/Aula_invertida)

# %% [markdown]
# ![diagramaTiempo.png](data:image/png;base64,...)
#
# **Figura 3:** Destino del tiempo invertido en una asignatura tradicional y en una de aula invertida.

# %% [markdown]
# - Teoría
#     - Se lee, e intenta aplicar en la resolución de ejercicios, **antes** del encuentro semanal.
#     - A través de un foro en línea se puede hacer consultas en todo momento.
#     - Cualquier duda remanente debe aclararse **durante** el encuentro.
# - Ejercicios
#     - Se inician **antes** del encuentro.
#     - Debe finalizarse **durante** el mismo, con ayuda del docente.
#     - La corrección se realiza **tras** el encuentro.

# %% [markdown]
# ### Organización del tiempo

# %% [markdown]
# - Esta modalidad requiere del alumno **mucha regularidad**.
# - Si espera al encuentro sincrónico para:
#   - leer teoría $\implies$ **no alcanza el tiempo**
#   - empezar los ejercicios $\implies$ **no alcanza el tiempo**
#   - ponerse _al día_ con lo adeudado de la semana anterior $\implies$ **no alcanza el tiempo**

# %% [markdown]
# | Actividad    | Curso tradicional | Aula invertida |
# | -------- | ------- |------- |
# | Presentación de nueva teoría  | Sincrónico | Asincrónico |
# | Ejemplos de resolución de ejercicios | Sincrónico | Asincrónico |
# | Consultas sobre teoría  | Sincrónico | Asincrónico y sincrónico |
# | Presentación de guías de ejercicios  | Sincrónico | Asincrónico |
# | Consultas sobre ejercicios  | Sincrónico | Asincrónico y sincrónico |
# | Resolución de ejercicios<br />(por el alumno)  | Asincrónico | Asincrónico (primordialmente)<br /> y sincrónico (cierre) |

# %% [markdown]
# ## Repositorio en línea del material de la asignatura

# %% [markdown]
# Para cada unidad temática hay una carpeta en el [repositorio de la asignatura](https://github.com/bettachini/UNLaM_MecanicaGeneral/) con cuadernos Jupyter de:
# - **Teoría** y **ejercicios resueltos**.
# - **Conjuntos de ejercicios** (pset): que se resuelven copiando y modificando ligeramente el código de los **ejercicios resueltos**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# **Figura 4:** En el README que se muestra en la portada del repositorio se muestran las temáticas y su material.
